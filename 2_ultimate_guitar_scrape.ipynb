# %% [markdown]
# # Ultimate Guitar Scrape - 2
# ## Scraping individual tabs
# *After initial scrape of the top 5,000 tabs on ultimate-guitar.com, scrape each individual tab for metadata/chords*
#
# ----
#
# **Final Project for Data & Databases**
#
# **C.J. Robinson**
#
# **Fall 2024**

# %% [markdown]
# -----
# ### Scrape song pages

# %%
import re
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from playwright.async_api import async_playwright

# %%
# read in initial data
top_songs_df = pd.read_csv("top_songs.csv")
top_songs_df.head()
# Out:
#    Unnamed: 0  rank         artist        artist_list  \
# 0           0     1     Ed Sheeran     ['Ed Sheeran']
# 1           1     2   Jeff Buckley   ['Jeff Buckley']
# 2           2     3  Elvis Presley  ['Elvis Presley']
# 3           3     4      Passenger      ['Passenger']
# 4           4     5    John Legend    ['John Legend']
#
#                         song ratings        hits    type  \
# 0                    Perfect  48,238  41,205,313  chords
# 1         Hallelujah (ver 2)  54,484  39,807,305  chords
# 2  Cant Help Falling In Love  32,809  33,890,059  chords
# 3                 Let Her Go  24,248  31,904,817  chords
# 4                  All Of Me  26,699  29,790,560  chords
#
#                                            song_link  \
# 0  https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 1  https://tabs.ultimate-guitar.com/tab/jeff-buck...
# 2  https://tabs.ultimate-guitar.com/tab/elvis-pre...
# 3  https://tabs.ultimate-guitar.com/tab/passenger...
# 4  https://tabs.ultimate-guitar.com/tab/john-lege...
#
#                                          artist_link  star_count
# 0  https://www.ultimate-guitar.com/artist/ed_shee...         5.0
# 1  https://www.ultimate-guitar.com/artist/jeff_bu...         5.0
# 2  https://www.ultimate-guitar.com/artist/elvis_p...         5.0
# 3  https://www.ultimate-guitar.com/artist/passeng...         5.0
# 4  https://www.ultimate-guitar.com/artist/john_le...         5.0

# %% [markdown]
# ### Loop through all the pages!

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

song_list = []
bad_urls_1k = []
counter = 0

for url in top_songs_df['song_link'][0:1000]:
    my_url = url
    #counter for progress
    counter += 1
    
    try:
        await page.goto(my_url, timeout=120000)
        time.sleep(3)
        #scroll down to get chords to actually load
        await page.evaluate("window.scrollTo(0, 2000)") 
        time.sleep(3)
        html = await page.content()
        
        soup_doc = BeautifulSoup(html, "html.parser")
        
        song_dict = {}
        song_dict['link'] = my_url
        
        #there's a bunch of metadata that may or may not be in the header
        #since it depends on the author
        #go through anything in that header and pull out metadata name and value
        try:
            for tag in soup_doc.find_all("th", class_ = "ZvOWv"):
                data_type = tag.text.lower()
                song_dict[data_type] = tag.next_sibling()[0].text
        except:
            print("No meta data")
            print(my_url)
        
        # only grab chord elements if it is chords, not tabs
        try:
            chord_list = []
            #pull all chords
            for chords in soup_doc.find_all("span", class_="_Oy28"):
                chord_list.append(chords.text)
        
            #get unique chord list
            song_dict['chord_list'] = list(set(chord_list))
            #also grab full text...just in case
            song_dict['full_text'] = soup_doc.find("pre", class_="tK8GG Ty_RP").text
        except:
            print("No chords")
        
        # get raw text of contributions, will regex later
        try:
            song_dict['contributors'] = soup_doc.find("span", class_="zku_4").text
        except:
            print("No contributors" + my_url)
        
        # get popularity raw, also will regex later
        try:
            song_dict['popularity'] = soup_doc.find("div", class_="_apVM").text
        except:
            print("No popularity" + my_url)
    
        song_list.append(song_dict)

    except:
        print("error with " + url)
        # get a list of errored URLS
        bad_urls_1k.append(url)

    if counter % 10 == 0:
        print(str(counter) + " / 1000 done") 
    
top_songs_df_meta = pd.json_normalize(song_list)
top_songs_df_meta.to_csv("top_songs_metadata_1k.csv", index = False)

bad_urls_1k_df = pd.DataFrame(bad_urls_1k, columns=["bad_urls"])
bad_urls_1k_df.to_csv('bad_urls_1k_df.csv', index=False)
# Out:
# Future exception was never retrieved
# future: <Future finished exception=Exception('Connection closed while reading from the driver')>
# Exception: Connection closed while reading from the driver
# Future exception was never retrieved
# future: <Future finished exception=Exception('Connection closed while reading from the driver')>
# Exception: Connection closed while reading from the driver
# No chords
# 10 / 1000 done
# No chords
# No chords
# 20 / 1000 done
# No chords
# 30 / 1000 done
# 40 / 1000 done
# No chords
# 50 / 1000 done
# No chords
# No chords
# No chords
# 60 / 1000 done
# No chords
# No chords
# 70 / 1000 done
# No chords
# No chords
# No chords
# 80 / 1000 done
# No chords
# 90 / 1000 done
# 100 / 1000 done
# No chords
# No chords
# 110 / 1000 done
# No chords
# No chords
# 120 / 1000 done
# 130 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/759809
# 140 / 1000 done
# No chords
# 150 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 160 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 170 / 1000 done
# 180 / 1000 done
# No chords
# No chords
# 190 / 1000 done
# No chords
# 200 / 1000 done
# 210 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/anji/menunggu-kamu-chords-2333561
# No chords
# 220 / 1000 done
# No chords
# 230 / 1000 done
# No chords
# 240 / 1000 done
# No chords
# No chords
# 250 / 1000 done
# No chords
# No chords
# No chords
# 260 / 1000 done
# No chords
# 270 / 1000 done
# No chords
# No chords
# 280 / 1000 done
# No chords
# 290 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/payphone-chords-1147850
# No chords
# No chords
# 300 / 1000 done
# No chords
# No chords
# 310 / 1000 done
# No chords
# error with https://tabs.ultimate-guitar.com/tab/guns-n-roses/patience-chords-775751
# No chords
# error with https://tabs.ultimate-guitar.com/tab/billie-eilish/happier-than-ever-chords-3592094
# 320 / 1000 done
# No chords
# No chords
# 330 / 1000 done
# No chords
# 340 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/beat-it-tabs-35178
# 350 / 1000 done
# No chords
# No chords
# No chords
# 360 / 1000 done
# 370 / 1000 done
# No chords
# No chords
# 380 / 1000 done
# No chords
# No chords
# 390 / 1000 done
# No chords
# 400 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/owl-city/fireflies-chords-849209
# 410 / 1000 done
# 420 / 1000 done
# 430 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/memories-chords-2831476
# 440 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 450 / 1000 done
# 460 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/roar-chords-1410981
# 470 / 1000 done
# No chords
# 480 / 1000 done
# No chords
# No chords
# 490 / 1000 done
# No chords
# 500 / 1000 done
# No chords
# 510 / 1000 done
# No chords
# No chords
# 520 / 1000 done
# No chords
# No chords
# 530 / 1000 done
# No chords
# No chords
# No chords
# 540 / 1000 done
# No chords
# No chords
# 550 / 1000 done
# No chords
# No chords
# 560 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/diamonds-chords-1185082
# No chords
# 570 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-beatles/here-comes-the-sun-tabs-17418
# 580 / 1000 done
# 590 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/charlie-puth/we-dont-talk-anymore-chords-1807087
# 600 / 1000 done
# No chords
# No chords
# No chords
# 610 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/miley-cyrus/wrecking-ball-chords-1414726
# 620 / 1000 done
# No chords
# No chords
# No chords
# 630 / 1000 done
# 640 / 1000 done
# No chords
# No chords
# No chords
# 650 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/jessie-j/price-tag-chords-1029351
# No chords
# 660 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/juan-karlos/ere-chords-4900969
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-righteous-brothers/unchained-melody-chords-82026
# No chords
# No chords
# 670 / 1000 done
# No chords
# 680 / 1000 done
# No chords
# No chords
# 690 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/payphone-chords-1149303
# 700 / 1000 done
# No chords
# No chords
# 710 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/the-one-that-got-away-chords-987143
# No chords
# 720 / 1000 done
# No chords
# No chords
# No chords
# 730 / 1000 done
# No chords
# No chords
# 740 / 1000 done
# No chords
# 750 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/misc-soundtrack/harry-potter-hedwigs-theme-tabs-258733
# No chords
# No chords
# error with #
# 760 / 1000 done
# No chords
# 770 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/jessie-j/price-tag-chords-1031439
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/the-one-that-got-away-chords-1240872
# No chords
# No chords
# 780 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/girls-like-you-chords-2226387
# 790 / 1000 done
# No chords
# 800 / 1000 done
# No chords
# 810 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/moira-dela-torre/tagpuan-chords-2297439
# No chords
# 820 / 1000 done
# No chords
# 830 / 1000 done
# No chords
# No chords
# 840 / 1000 done
# No chords
# No chords
# 850 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/sugar-chords-1517227
# No chords
# No chords
# 860 / 1000 done
# No chords
# 870 / 1000 done
# 880 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/december-avenue/huling-sandali-chords-2656311
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lp/lost-on-you-chords-1825835
# 890 / 1000 done
# 900 / 1000 done
# No chords
# 910 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-beatles/norwegian-wood-chords-1050930
# 920 / 1000 done
# No chords
# No chords
# 930 / 1000 done
# No chords
# 940 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/i-belong-to-the-zoo/balang-araw-chords-2438883
# 950 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 960 / 1000 done
# 970 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/taio-cruz/dynamite-chords-961594
# 980 / 1000 done
# No chords
# No chords
# 990 / 1000 done
# No chords
# No chords
# 1000 / 1000 done

# %%
# top_songs_df = pd.json_normalize(song_list)
# top_songs_df.to_csv("top_songs_metadata_1k.csv", index = False)

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

song_list_2k = []
bad_urls_2k = []
counter = 0

for url in top_songs_df['song_link'][1000:2000]:
    my_url = url
    #counter for progress
    counter += 1
    
    try:
        await page.goto(my_url, timeout=120000)
        time.sleep(3)
        #scroll down to get chords to actually load
        await page.evaluate("window.scrollTo(0, 2000)") 
        time.sleep(3)
        html = await page.content()
        
        soup_doc = BeautifulSoup(html, "html.parser")
        
        song_dict = {}
        song_dict['link'] = my_url
        
        #there's a bunch of metadata that may or may not be in the header
        #since it depends on the author
        #go through anything in that header and pull out metadata name and value
        try:
            for tag in soup_doc.find_all("th", class_ = "ZvOWv"):
                data_type = tag.text.lower()
                song_dict[data_type] = tag.next_sibling()[0].text
        except:
            print("No meta data")
            print(my_url)
        
        # only grab chord elements if it is chords, not tabs
        try:
            chord_list = []
            #pull all chords
            for chords in soup_doc.find_all("span", class_="_Oy28"):
                chord_list.append(chords.text)
        
            #get unique chord list
            song_dict['chord_list'] = list(set(chord_list))
            #also grab full text...just in case
            song_dict['full_text'] = soup_doc.find("pre", class_="tK8GG Ty_RP").text
        except:
            print("No chords")
        
        # get raw text of contributions, will regex later
        try:
            song_dict['contributors'] = soup_doc.find("span", class_="zku_4").text
        except:
            print("No contributors" + my_url)
        
        # get popularity raw, also will regex later
        try:
            song_dict['popularity'] = soup_doc.find("div", class_="_apVM").text
        except:
            print("No popularity" + my_url)
    
        song_list_2k.append(song_dict)

    except:
        print("error with " + url)
        # get a list of errored URLS
        bad_urls_2k.append(url)

    if counter % 10 == 0:
        print(str(counter) + " / 1000 done") 
    
top_songs_df_meta_2k = pd.json_normalize(song_list_2k)
top_songs_df_meta_2k.to_csv("top_songs_metadata_2k.csv", index = False)

bad_urls_2k_df = pd.DataFrame(bad_urls_2k, columns=["bad_urls"])
bad_urls_2k_df.to_csv('bad_urls_2k_df.csv', index=False)
# Out:
# Future exception was never retrieved
# future: <Future finished exception=Exception('Connection closed while reading from the driver')>
# Exception: Connection closed while reading from the driver
# Future exception was never retrieved
# future: <Future finished exception=Exception('Connection closed while reading from the driver')>
# Exception: Connection closed while reading from the driver
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/759410
# 10 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/fourfiveseconds-chords-1705341
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/california-king-bed-chords-1004189
# 20 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/guns-n-roses/sweet-child-o-mine-guitar-pro-220689
# 30 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/love-on-the-brain-chords-1809471
# 40 / 1000 done
# No chords
# No chords
# 50 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/heal-the-world-chords-71843
# 60 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 70 / 1000 done
# No chords
# 80 / 1000 done
# No chords
# 90 / 1000 done
# 100 / 1000 done
# No chords
# No chords
# 110 / 1000 done
# No chords
# No chords
# No chords
# 120 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/neil-young/harvest-moon-chords-73
# No chords
# 130 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/i-kissed-a-girl-chords-684047
# No chords
# 140 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/594514
# 150 / 1000 done
# No chords
# 160 / 1000 done
# No chords
# 170 / 1000 done
# 180 / 1000 done
# No chords
# No chords
# 190 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/teenage-dream-chords-970774
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/billie-jean-chords-258773
# 200 / 1000 done
# 210 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/charlie-puth/attention-chords-1986333
# No chords
# No chords
# 220 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/payphone-chords-1148461
# No chords
# 230 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 240 / 1000 done
# No chords
# 250 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/neil-young/the-needle-and-the-damage-done-tabs-77
# No chords
# No chords
# No chords
# 260 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/bill-withers/lean-on-me-bass-173
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/beat-it-chords-71842
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/miley-cyrus/wrecking-ball-chords-1414450
# 270 / 1000 done
# No chords
# No chords
# No chords
# 280 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/moira-dela-torre/sundo-chords-2205057
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/neil-young/heart-of-gold-bass-81
# No chords
# No chords
# 290 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/billie-jean-chords-126646
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zz-top/tube-snake-boogie-tabs-32
# 300 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/yes/long-distance-runaround-bass-92
# No chords
# 310 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/x/los-angeles-chords-118
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-chainsmokers/dont-let-me-down-chords-1818535
# No chords
# No chords
# 320 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/u2/bad-bass-746
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/yello/oh-yeah-bass-65
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-youngbloods/get-together-bass-63
# No chords
# 330 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ween/the-hiv-song-tabs-223
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-who/you-better-you-bet-bass-192
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/yes/tales-from-topographic-oceans-tabs-89
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/whigfield/saturday-night-bass-143
# 340 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/frank-zappa/echidnas-arf-of-you-bass-11
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/paul-weller/the-changingman-bass-155
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zz-top/cheap-sunglasses-bass-41
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/get-back-tabs-54
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zz-top/burger-man-tabs-24
# 350 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/neil-young/such-a-woman-tabs-78
# No chords
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ween/nicole-bass-238
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zeke/twisted-bass-2
# 360 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/wasted-tabs-52
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/weezer/the-christmas-song-bass-380
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/jag-off-bass-56
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/check-tabs-51
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zed/renegade-fighter-tabs-45
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-vandals/urban-struggle-bass-523
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-ws/the-devil-is-bad-bass-162
# No chords
# 370 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zoinks/page-5-bass-8
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/youth-brigade/spies-for-life-bass-62
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zilch/everything-bass-9
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/veruca-salt/used-to-know-her-tabs-618
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/xtc/the-ballad-of-peter-pumpkinhead-tabs-111
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/yes/tempus-fugit-bass-98
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-weakerthans/diagnosis-bass-137
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/robbie-williams/old-before-i-die-bass-302
# 380 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/white-kaps/american-dream-bass-198
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/in-my-room-tabs-47
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/now-or-never-bass-59
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/value-pac/we-are-the-ones-bass-510
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/you-am-i/mr-milk-bass-68
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-ws/dexter-bass-159
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/xtc/my-bird-performs-tabs-108
# 390 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/wd40/crying-tabs-131
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/weston/retarded-bass-177
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/xtc/then-she-appeared-tabs-114
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/xtc/holly-up-on-poppy-tabs-107
# No contributorshttps://tabs.ultimate-guitar.com/tab/xtc/ball-and-chain-chords-105
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/neil-young/i-shall-be-released-bass-87
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-yardbirds/over-under-sideways-down-bass-72
# No chords
# 400 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/i-am-bass-57
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/playmate-of-the-year-tabs-49
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/wasted-time/rampage-bass-153
# No chords
# 410 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/wu-tang-clan/clan-in-da-front-bass-132
# No chords
# 420 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/zebrahead/playmate-of-the-year-bass-55
# 430 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-who/naked-eye-bass-195
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/verdena/valvonauta-bass-546
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/young-mc/principals-office-bass-67
# 440 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/misc-musicals/jesus-christ-superstar-heaven-on-their-minds-bass-134
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/vision-of-disorder/jada-bloom-bass-501
# No chords
# No chords
# 450 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/bob-marley/one-love-people-get-ready-chords-641253
# No chords
# No chords
# 460 / 1000 done
# No chords
# No chords
# No chords
# 470 / 1000 done
# No chords
# No chords
# No chords
# 480 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/jessie-j/price-tag-chords-1066039
# No chords
# 490 / 1000 done
# No chords
# 500 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/u2/always-bass-811
# 510 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-yardbirds/the-train-kept-a-rollin-bass-70
# No chords
# No chords
# 520 / 1000 done
# No chords
# No chords
# 530 / 1000 done
# No chords
# No chords
# 540 / 1000 done
# No chords
# 550 / 1000 done
# No chords
# 560 / 1000 done
# No chords
# No chords
# No chords
# 570 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/guns-n-roses/patience-chords-12726
# 580 / 1000 done
# No chords
# No chords
# 590 / 1000 done
# No chords
# 600 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/avril-lavigne/keep-holding-on-chords-436380
# 610 / 1000 done
# No chords
# 620 / 1000 done
# 630 / 1000 done
# No chords
# No chords
# 640 / 1000 done
# 650 / 1000 done
# No chords
# No chords
# 660 / 1000 done
# No chords
# No chords
# No chords
# 670 / 1000 done
# No chords
# No chords
# No chords
# 680 / 1000 done
# No chords
# No chords
# 690 / 1000 done
# No chords
# 700 / 1000 done
# No chords
# No chords
# No chords
# 710 / 1000 done
# No chords
# 720 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/fourfiveseconds-chords-1705925
# 730 / 1000 done
# No chords
# 740 / 1000 done
# No chords
# 750 / 1000 done
# No chords
# No chords
# 760 / 1000 done
# No chords
# No chords
# 770 / 1000 done
# No chords
# 780 / 1000 done
# 790 / 1000 done
# No chords
# No chords
# No chords
# 800 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 810 / 1000 done
# 820 / 1000 done
# No chords
# 830 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/johann-pachelbel/canon-in-d-chords-1092203
# No chords
# 840 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rixton/me-and-my-broken-heart-chords-1473578
# 850 / 1000 done
# No chords
# 860 / 1000 done
# No chords
# No chords
# 870 / 1000 done
# No chords
# 880 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 890 / 1000 done
# No chords
# No chords
# 900 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/beat-it-tabs-46048
# No chords
# 910 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/maps-chords-1493701
# No chords
# 920 / 1000 done
# 930 / 1000 done
# No chords
# 940 / 1000 done
# No chords
# No chords
# No chords
# 950 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/alessia-cara/scars-to-your-beautiful-chords-1789184
# 960 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ed-sheeran/dont-chords-1476269
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/gym-class-heroes/stereo-hearts-chords-1093324
# 970 / 1000 done
# error with #
# No chords
# 980 / 1000 done
# No chords
# No chords
# 990 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/abba/dancing-queen-chords-52942
# No chords
# 1000 / 1000 done

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

song_list_3k = []
bad_urls_3k = []
counter = 0

for url in top_songs_df['song_link'][2000:3000]:
    my_url = url
    #counter for progress
    counter += 1
    
    try:
        await page.goto(my_url, timeout=120000)
        time.sleep(2)
        #scroll down to get chords to actually load
        await page.evaluate("window.scrollTo(0, 2000)") 
        time.sleep(2)
        html = await page.content()
        
        soup_doc = BeautifulSoup(html, "html.parser")
        
        song_dict = {}
        song_dict['link'] = my_url
        
        #there's a bunch of metadata that may or may not be in the header
        #since it depends on the author
        #go through anything in that header and pull out metadata name and value
        try:
            for tag in soup_doc.find_all("th", class_ = "ZvOWv"):
                data_type = tag.text.lower()
                song_dict[data_type] = tag.next_sibling()[0].text
        except:
            print("No meta data")
            print(my_url)
        
        # only grab chord elements if it is chords, not tabs
        try:
            chord_list = []
            #pull all chords
            for chords in soup_doc.find_all("span", class_="_Oy28"):
                chord_list.append(chords.text)
        
            #get unique chord list
            song_dict['chord_list'] = list(set(chord_list))
            #also grab full text...just in case
            song_dict['full_text'] = soup_doc.find("pre", class_="tK8GG Ty_RP").text
        except:
            print("No chords")
        
        # get raw text of contributions, will regex later
        try:
            song_dict['contributors'] = soup_doc.find("span", class_="zku_4").text
        except:
            print("No contributors" + my_url)
        
        # get popularity raw, also will regex later
        try:
            song_dict['popularity'] = soup_doc.find("div", class_="_apVM").text
        except:
            print("No popularity" + my_url)
    
        song_list_3k.append(song_dict)

    except:
        print("error with " + url)
        # get a list of errored URLS
        bad_urls_3k.append(url)

    if counter % 10 == 0:
        print(str(counter) + " / 1000 done") 
    
top_songs_df_meta_3k = pd.json_normalize(song_list_3k)
top_songs_df_meta_3k.to_csv("top_songs_metadata_3k.csv", index = False)

bad_urls_3k_df = pd.DataFrame(bad_urls_3k, columns=["bad_urls"])
bad_urls_3k_df.to_csv('bad_urls_3k_df.csv', index=False)
# Out:
# No chords
# 10 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/bob-dylan/girl-from-the-north-country-chords-1087317
# No chords
# 20 / 1000 done
# No chords
# 30 / 1000 done
# No chords
# No chords
# No chords
# 40 / 1000 done
# No chords
# No chords
# 50 / 1000 done
# No chords
# No chords
# 60 / 1000 done
# No chords
# 70 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/one-direction/perfect-chords-1774305
# No chords
# No chords
# 80 / 1000 done
# No chords
# 90 / 1000 done
# 100 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-itchyworms/di-na-muli-chords-2413785
# No chords
# No chords
# No chords
# No chords
# 110 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/hivi/remaja-chords-1980289
# 120 / 1000 done
# No chords
# No chords
# No chords
# 130 / 1000 done
# No chords
# 140 / 1000 done
# No chords
# error with #
# No chords
# 150 / 1000 done
# No chords
# 160 / 1000 done
# No chords
# 170 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ed-sheeran/dont-chords-1476461
# No chords
# No chords
# error with #
# 180 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lionel-richie/hello-chords-33913
# No chords
# 190 / 1000 done
# No chords
# No chords
# 200 / 1000 done
# No chords
# No chords
# 210 / 1000 done
# 220 / 1000 done
# No chords
# 230 / 1000 done
# No chords
# 240 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-beatles/ive-just-seen-a-face-chords-1061795
# No chords
# No chords
# No chords
# 250 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 260 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/1090813
# No chords
# No chords
# 270 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/dilaw/uhaw-tayong-lahat-chords-4612418
# No chords
# No chords
# 280 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 290 / 1000 done
# 300 / 1000 done
# No chords
# No chords
# No chords
# 310 / 1000 done
# No chords
# 320 / 1000 done
# No chords
# No chords
# No chords
# 330 / 1000 done
# No chords
# No chords
# 340 / 1000 done
# No chords
# No chords
# No chords
# 350 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/sugar-chords-1515715
# 360 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/california-king-bed-tabs-1005230
# No chords
# 370 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/benben/pagtingin-chords-2683692
# 380 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/dua-lipa/new-rules-chords-2079521
# 390 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/olivia-rodrigo/deja-vu-chords-3640262
# 400 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/arthur-nery/binhi-chords-3059212
# No chords
# 410 / 1000 done
# No chords
# No chords
# No chords
# 420 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/hot-n-cold-chords-700455
# 430 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/wide-awake-chords-1140152
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/everlast/what-its-like-tabs-14346
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-juans/hindi-tayo-pwede-chords-2754906
# 440 / 1000 done
# 450 / 1000 done
# No chords
# 460 / 1000 done
# 470 / 1000 done
# No chords
# No chords
# 480 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/human-nature-chords-212731
# No chords
# No chords
# No chords
# 490 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 500 / 1000 done
# No chords
# No chords
# No chords
# 510 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/r-city/locked-away-chords-1749374
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/martin-garrix/scared-to-be-lonely-chords-1938851
# 520 / 1000 done
# No chords
# 530 / 1000 done
# No chords
# No chords
# 540 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/victory-worship/tribes-chords-2597475
# 550 / 1000 done
# No chords
# No chords
# 560 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/dark-horse-chords-1419861
# No chords
# 570 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lady-gaga/telephone-chords-900508
# No chords
# No chords
# No chords
# 580 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/deep-purple/smoke-on-the-water-chords-1088508
# No chords
# No chords
# No chords
# 590 / 1000 done
# No chords
# 600 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 610 / 1000 done
# No chords
# No chords
# 620 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/clean-bandit/rockabye-chords-1897251
# No chords
# No chords
# 630 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rage-against-the-machine/killing-in-the-name-tabs-90202
# No chords
# 640 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/paul-mccartney/maybe-im-amazed-chords-202741
# 650 / 1000 done
# No chords
# 660 / 1000 done
# No chords
# No chords
# 670 / 1000 done
# 680 / 1000 done
# 690 / 1000 done
# No chords
# 700 / 1000 done
# No chords
# No chords
# 710 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rick-astley/never-gonna-give-you-up-chords-521741
# 720 / 1000 done
# error with #
# No chords
# No chords
# No chords
# 730 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/thriller-chords-212734
# No chords
# 740 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 750 / 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/miley-cyrus/party-in-the-usa-chords-855018
# No chords
# 760 / 1000 done
# No chords
# No chords
# 770 / 1000 done
# No chords
# 780 / 1000 done
# No chords
# No chords
# 790 / 1000 done
# No chords
# No chords
# 800 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 810 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/tones-and-i/dance-monkey-chords-2851940
# No contributorshttps://tabs.ultimate-guitar.com/tab/kate-bush/running-up-that-hill-chords-1520628
# No chords
# 820 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/fleetwood-mac/landslide-chords-1048613
# 830 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/andra-and-the-backbone/sempurna-chords-2365905
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lionel-richie/stuck-on-you-chords-409677
# 840 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/kesha/tik-tok-chords-888737
# No chords
# 850 / 1000 done
# No chords
# 860 / 1000 done
# No chords
# No chords
# 870 / 1000 done
# No chords
# No chords
# 880 / 1000 done
# No chords
# 890 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 900 / 1000 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/billie-jean-chords-855230
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/beat-it-tabs-99197
# 910 / 1000 done
# 920 / 1000 done
# No chords
# No chords
# 930 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 940 / 1000 done
# No chords
# No chords
# No chords
# 950 / 1000 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rage-against-the-machine/killing-in-the-name-tabs-4482
# No chords
# 960 / 1000 done
# 970 / 1000 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/djo/end-of-beginning-chords-4351838
# No chords
# No chords
# No chords
# 980 / 1000 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/memories-chords-2831503
# 990 / 1000 done
# No chords
# No chords
# No chords
# No chords
# 1000 / 1000 done

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

song_list_4k = []
bad_urls_4k = []
counter = 0

for url in top_songs_df['song_link'][3000:5000]:
    my_url = url
    #counter for progress
    counter += 1
    
    try:
        await page.goto(my_url, timeout=120000)
        time.sleep(2)
        #scroll down to get chords to actually load
        await page.evaluate("window.scrollTo(0, 2000)") 
        time.sleep(2)
        html = await page.content()
        
        soup_doc = BeautifulSoup(html, "html.parser")
        
        song_dict = {}
        song_dict['link'] = my_url
        
        #there's a bunch of metadata that may or may not be in the header
        #since it depends on the author
        #go through anything in that header and pull out metadata name and value
        try:
            for tag in soup_doc.find_all("th", class_ = "ZvOWv"):
                data_type = tag.text.lower()
                song_dict[data_type] = tag.next_sibling()[0].text
        except:
            print("No meta data")
            print(my_url)
        
        # only grab chord elements if it is chords, not tabs
        try:
            chord_list = []
            #pull all chords
            for chords in soup_doc.find_all("span", class_="_Oy28"):
                chord_list.append(chords.text)
        
            #get unique chord list
            song_dict['chord_list'] = list(set(chord_list))
            #also grab full text...just in case
            song_dict['full_text'] = soup_doc.find("pre", class_="tK8GG Ty_RP").text
        except:
            print("No chords")
        
        # get raw text of contributions, will regex later
        try:
            song_dict['contributors'] = soup_doc.find("span", class_="zku_4").text
        except:
            print("No contributors" + my_url)
        
        # get popularity raw, also will regex later
        try:
            song_dict['popularity'] = soup_doc.find("div", class_="_apVM").text
        except:
            print("No popularity" + my_url)
    
        song_list_4k.append(song_dict)

    except:
        print("error with " + url)
        # get a list of errored URLS
        bad_urls_4k.append(url)

    if counter % 10 == 0:
        print(str(counter) + " done") 
    
top_songs_df_meta_4k = pd.json_normalize(song_list_4k)
top_songs_df_meta_4k.to_csv("top_songs_metadata_4k.csv", index = False)

bad_urls_4k_df = pd.DataFrame(bad_urls_4k, columns=["bad_urls"])
bad_urls_4k_df.to_csv('bad_urls_4k_df.csv', index=False)
# Out:
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/kelly-clarkson/since-u-been-gone-chords-148473
# No contributorshttps://tabs.ultimate-guitar.com/tab/supertramp/give-a-little-bit-chords-1087315
# No chords
# No chords
# 10 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/metallica/nothing-else-matters-video-1024840
# 20 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/dua-lipa/idgaf-chords-2064489
# 30 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 40 done
# No chords
# No chords
# 50 done
# No chords
# No chords
# No chords
# No chords
# 60 done
# No chords
# No chords
# No chords
# No chords
# 70 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/animals-chords-1513699
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/teenage-dream-chords-972550
# No chords
# 80 done
# No chords
# No chords
# 90 done
# No chords
# 100 done
# No chords
# No chords
# No chords
# 110 done
# 120 done
# No chords
# No chords
# No chords
# 130 done
# No chords
# 140 done
# No chords
# No chords
# 150 done
# No chords
# No chords
# 160 done
# No chords
# No chords
# No chords
# 170 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/december-avenue/kahit-di-mo-alam-chords-2162195
# 180 done
# No chords
# No chords
# No chords
# 190 done
# No chords
# No chords
# 200 done
# 210 done
# No chords
# 220 done
# No chords
# 230 done
# No chords
# No chords
# No chords
# 240 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/acdc/back-in-black-guitar-pro-403348
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/moves-like-jagger-chords-1074594
# No chords
# 250 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/boyzone/when-you-say-nothing-at-all-chords-62421
# No chords
# 260 done
# No chords
# 270 done
# No chords
# 280 done
# No chords
# No chords
# No chords
# 290 done
# No chords
# No chords
# No chords
# No chords
# 300 done
# No chords
# 310 done
# No chords
# 320 done
# No chords
# No chords
# 330 done
# No chords
# 340 done
# No chords
# 350 done
# No chords
# No chords
# 360 done
# No chords
# No chords
# No chords
# No chords
# 370 done
# No chords
# 380 done
# No chords
# 390 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/diamonds-chords-1198110
# No chords
# 400 done
# No chords
# 410 done
# No chords
# No chords
# 420 done
# No chords
# 430 done
# No chords
# 440 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/black-or-white-chords-71848
# No chords
# No chords
# No chords
# 450 done
# No chords
# 460 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ne-yo/so-sick-chords-982404
# 470 done
# No chords
# 480 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/joji/glimpse-of-us-chords-4228723
# No chords
# 490 done
# No chords
# 500 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/clean-bandit/symphony-chords-1965137
# 510 done
# No chords
# No chords
# 520 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/pnk/who-knew-chords-366857
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/u2/beautiful-day-chords-816
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/deep-purple/smoke-on-the-water-guitar-pro-217612
# No chords
# 530 done
# 540 done
# No chords
# No chords
# No chords
# No chords
# 550 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lewis-capaldi/forever-chords-2696523
# 560 done
# No chords
# error with #
# No chords
# No chords
# No chords
# 570 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/alan-walker/lily-chords-2544717
# 580 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/smooth-criminal-chords-162913
# No chords
# 590 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/dua-lipa/dont-start-now-chords-2878802
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-beatles/let-it-be-tabs-183356
# No chords
# No chords
# 600 done
# No chords
# 610 done
# No chords
# No chords
# 620 done
# No chords
# No chords
# No chords
# No chords
# 630 done
# No chords
# No chords
# No chords
# 640 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/cyndi-lauper/silent-night-chords-604451
# No chords
# No chords
# No chords
# 650 done
# No chords
# error with #
# No chords
# 660 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/california-king-bed-chords-1057199
# No chords
# 670 done
# No chords
# No chords
# 680 done
# No chords
# No chords
# No chords
# 690 done
# No chords
# No chords
# 700 done
# No chords
# No chords
# No chords
# No chords
# 710 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/troye-sivan/youth-chords-1775184
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/grover-washington-jr-/just-the-two-of-us-chords-1229441
# No popularityhttps://tabs.ultimate-guitar.com/tab/grover-washington-jr-/just-the-two-of-us-chords-1229441
# 720 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/metallica/the-day-that-never-comes-guitar-pro-723163
# No chords
# No chords
# 730 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/billie-jean-bass-634491
# No chords
# No chords
# No chords
# 740 done
# No chords
# No chords
# No chords
# 750 done
# No chords
# 760 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/audioslave/like-a-stone-chords-449485
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/christina-perri/jar-of-hearts-chords-966281
# No chords
# 770 done
# No chords
# 780 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lauv/i-like-me-better-chords-2093225
# No chords
# 790 done
# No chords
# No chords
# No chords
# error with #
# No chords
# 800 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lionel-richie/hello-chords-1004004
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/lionel-richie/endless-love-chords-147821
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-calling/wherever-you-will-go-chords-25142
# 810 done
# No chords
# No chords
# No chords
# No chords
# 820 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/jose-mari-chan/christmas-in-our-hearts-chords-64587
# No chords
# 830 done
# No chords
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/destinys-child/say-my-name-chords-126633
# 840 done
# No chords
# 850 done
# No chords
# No chords
# No chords
# No chords
# 860 done
# No chords
# No chords
# 870 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/jessie-j/domino-chords-1109843
# 880 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/kelly-clarkson/my-life-would-suck-without-you-chords-778794
# No chords
# 890 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-beatles/sgt-peppers-lonely-hearts-club-band-tabs-182733
# No chords
# No chords
# 900 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/bob-marley/one-love-people-get-ready-chords-75884
# No chords
# No chords
# 910 done
# No chords
# 920 done
# No chords
# No chords
# 930 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 940 done
# 950 done
# No chords
# 960 done
# No chords
# 970 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/miley-cyrus/party-in-the-usa-chords-1227643
# No chords
# 980 done
# No chords
# No chords
# 990 done
# No chords
# 1000 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/california-gurls-chords-951401
# No chords
# No chords
# No chords
# 1010 done
# 1020 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/misc-musicals/wicked-defying-gravity-chords-666192
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/onerepublic/something-i-need-chords-1233452
# 1030 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/teenage-dream-chords-972275
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/misc-soundtrack/harry-potter-hedwigs-theme-tabs-700581
# No chords
# No chords
# 1040 done
# No chords
# No chords
# 1050 done
# No chords
# 1060 done
# No chords
# No chords
# 1070 done
# No chords
# 1080 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/et-chords-988479
# 1090 done
# No chords
# No chords
# 1100 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/benben/maybe-the-night-chords-2220511
# No chords
# No chords
# 1110 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/harry-styles/cherry-chords-2926985
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ariana-grande/love-me-harder-chords-1513385
# No chords
# No chords
# 1120 done
# No chords
# No chords
# 1130 done
# 1140 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 1150 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/the-beatles/lucy-in-the-sky-with-diamonds-chords-1049325
# No chords
# 1160 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/taylor-swift/my-tears-ricochet-chords-3261299
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/payphone-tabs-1161705
# 1170 done
# No chords
# No chords
# No chords
# No chords
# 1180 done
# No chords
# No chords
# 1190 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/unconditionally-chords-1425968
# No chords
# No chords
# 1200 done
# No chords
# No chords
# No chords
# No chords
# 1210 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/john-williams/star-wars-the-imperial-march-darth-vaders-theme-tabs-618403
# No chords
# 1220 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/james-blunt/monsters-chords-2860760
# No chords
# 1230 done
# No chords
# No chords
# No chords
# 1240 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rihanna/diamonds-chords-1185460
# No contributorshttps://tabs.ultimate-guitar.com/tab/chris-tomlin/holy-forever-chords-4273513
# 1250 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/katy-perry/the-one-that-got-away-chords-1116485
# 1260 done
# No chords
# No chords
# 1270 done
# No chords
# 1280 done
# No chords
# 1290 done
# No chords
# 1300 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/jessie-j/price-tag-chords-1196024
# No chords
# 1310 done
# 1320 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/guns-n-roses/dont-cry-guitar-pro-220589
# No chords
# 1330 done
# No chords
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/miley-cyrus/wrecking-ball-chords-1414544
# 1340 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/charlie-puth/attention-chords-1984321
# 1350 done
# No chords
# No chords
# No chords
# 1360 done
# 1370 done
# 1380 done
# No chords
# No chords
# No chords
# No chords
# 1390 done
# No chords
# No chords
# 1400 done
# No chords
# No chords
# No chords
# No chords
# 1410 done
# No chords
# No chords
# No chords
# No chords
# 1420 done
# No chords
# No chords
# 1430 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/kesha/praying-chords-2078159
# No chords
# 1440 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/maroon-5/payphone-chords-1147920
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/1072356
# 1450 done
# No chords
# No chords
# 1460 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/hindia/membasuh-chords-2768230
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/gym-class-heroes/stereo-hearts-chords-1070522
# error with #
# 1470 done
# No chords
# 1480 done
# No chords
# 1490 done
# No chords
# No chords
# No chords
# No chords
# 1500 done
# 1510 done
# No chords
# No chords
# 1520 done
# No chords
# No chords
# No chords
# 1530 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/aj-rafael/she-was-mine-chords-978128
# No chords
# 1540 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/misc-christmas/baby-its-cold-outside-chords-1427909
# No contributorshttps://tabs.ultimate-guitar.com/tab/mark-ronson/nothing-breaks-like-a-heart-chords-2531568
# 1550 done
# No chords
# No chords
# No chords
# 1560 done
# No chords
# No chords
# No chords
# No chords
# 1570 done
# No chords
# No chords
# 1580 done
# No chords
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/oasis/wonderwall-guitar-pro-227425
# 1590 done
# 1600 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/harry-chapin/cats-in-the-cradle-chords-1092206
# 1610 done
# No chords
# No chords
# 1620 done
# No chords
# No chords
# No chords
# 1630 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/miley-cyrus/wrecking-ball-chords-1414394
# No chords
# No chords
# No chords
# 1640 done
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/michael-jackson/billie-jean-tabs-100854
# No chords
# 1650 done
# No chords
# No chords
# No chords
# error with #
# No chords
# 1660 done
# No chords
# 1670 done
# No chords
# No chords
# 1680 done
# No chords
# No chords
# No chords
# 1690 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/ne-yo/so-sick-chords-969280
# 1700 done
# No chords
# No chords
# No chords
# No chords
# 1710 done
# No chords
# No chords
# 1720 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/stevie-wonder/isnt-she-lovely-chords-319062
# No chords
# 1730 done
# No chords
# No chords
# No chords
# 1740 done
# No chords
# No chords
# No chords
# 1750 done
# No chords
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/justin-bieber/boyfriend-chords-1140842
# 1760 done
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/eric-clapton/tears-in-heaven-guitar-pro-216691
# No contributorshttps://tabs.ultimate-guitar.com/tab/jimmy-bondoc/hanggang-dito-na-lang-chords-1809792
# No chords
# No chords
# 1770 done
# No chords
# No chords
# No chords
# No chords
# No chords
# 1780 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/dilaw/janice-chords-4250626
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/kelly-clarkson/behind-these-hazel-eyes-chords-186608
# No contributorshttps://tabs.ultimate-guitar.com/tab/pink-guy/stfu-chords-1877884
# No chords
# 1790 done
# 1800 done
# No chords
# No chords
# 1810 done
# No chords
# No chords
# No chords
# 1820 done
# No contributorshttps://tabs.ultimate-guitar.com/tab/maximillian-denmark/beautiful-scars-chords-3020456
# 1830 done
# No chords
# No chords
# 1840 done
# No chords
# No chords
# 1850 done
# No chords
# No chords
# 1860 done
# No chords
# No chords
# 1870 done
# No chords
# No chords
# No chords
# 1880 done
# No chords
# No chords
# error with #
# 1890 done
# error with https://tabs.ultimate-guitar.com/tab/third-eye-blind/jumper-tabs-136734
# error with https://tabs.ultimate-guitar.com/tab/the-white-stripes/dead-leaves-and-the-dirty-ground-tabs-37033
# error with https://tabs.ultimate-guitar.com/tab/the-killers/when-you-were-young-chords-499348
# error with https://tabs.ultimate-guitar.com/tab/dani-and-lizzy/dancing-in-the-sky-chords-1423105
# error with https://tabs.ultimate-guitar.com/tab/lessons-scales/major-and-minor-scales-bass-42016
# error with https://tabs.ultimate-guitar.com/tab/sade/smooth-operator-chords-58277
# error with https://tabs.ultimate-guitar.com/tab/eminem/the-monster-chords-1428435
# error with https://tabs.ultimate-guitar.com/tab/parokya-ni-edgar/harana-chords-187879
# error with https://tabs.ultimate-guitar.com/tab/misc-soundtrack/the-greatest-showman-tightrope-chords-2268115
# error with https://tabs.ultimate-guitar.com/tab/thin-lizzy/got-to-give-it-up-guitar-pro-545477
# 1900 done
# error with https://tabs.ultimate-guitar.com/tab/misc-musicals/hamilton-dear-theodosia-chords-1775670
# error with https://tabs.ultimate-guitar.com/tab/the-devil-makes-three/old-number-7-chords-761428
# error with https://tabs.ultimate-guitar.com/tab/the-beatles/hey-jude-tabs-828780
# error with https://tabs.ultimate-guitar.com/tab/coldplay/the-scientist-chords-1790735
# error with https://tabs.ultimate-guitar.com/tab/bob-marley/buffalo-soldier-chords-260975
# error with https://tabs.ultimate-guitar.com/tab/chris-tomlin/at-the-cross-love-ran-red-chords-1463998
# error with https://tabs.ultimate-guitar.com/tab/simple-plan/perfect-chords-968191
# error with https://tabs.ultimate-guitar.com/tab/celine-dion/its-all-coming-back-to-me-now-chords-1001570
# error with https://tabs.ultimate-guitar.com/tab/he-is-we/all-about-us-chords-1009597
# error with https://tabs.ultimate-guitar.com/tab/zac-brown-band/knee-deep-chords-991228
# 1910 done
# error with https://tabs.ultimate-guitar.com/tab/the-monkees/im-a-believer-chords-186969
# error with https://tabs.ultimate-guitar.com/tab/duffy/mercy-chords-633994
# error with https://tabs.ultimate-guitar.com/tab/red-hot-chili-peppers/by-the-way-chords-954593
# error with https://tabs.ultimate-guitar.com/tab/misc-soundtrack/mamma-mia-dancing-queen-chords-3217598
# error with https://tabs.ultimate-guitar.com/tab/kanye-west/heartless-chords-741960
# error with https://tabs.ultimate-guitar.com/tab/blind-guardian/the-bards-song-in-the-forest-tabs-60474
# error with https://tabs.ultimate-guitar.com/tab/honne/location-unknown-chords-2551191
# error with https://tabs.ultimate-guitar.com/tab/david-kushner/daylight-chords-4695719
# error with https://tabs.ultimate-guitar.com/tab/midland/drinkin-problem-chords-1908704
# error with https://tabs.ultimate-guitar.com/tab/queens-of-the-stone-age/3s-and-7s-tabs-592489
# 1920 done
# error with https://tabs.ultimate-guitar.com/tab/mac-demarco/chamber-of-reflection-chords-1726363
# error with https://tabs.ultimate-guitar.com/tab/twenty-one-pilots/car-radio-chords-1208267
# error with https://tabs.ultimate-guitar.com/tab/charlie-puth/marvin-gaye-chords-1741228
# error with https://tabs.ultimate-guitar.com/tab/barenaked-ladies/god-rest-ye-merry-gentlemen-chords-765488
# error with https://tabs.ultimate-guitar.com/tab/elliott-smith/needle-in-the-hay-chords-84527
# error with https://tabs.ultimate-guitar.com/tab/thirty-seconds-to-mars/the-kill-tabs-369642
# error with https://tabs.ultimate-guitar.com/tab/the-beatles/i-feel-fine-tabs-55741
# error with https://tabs.ultimate-guitar.com/tab/the-police/every-breath-you-take-chords-327965
# error with https://tabs.ultimate-guitar.com/tab/queen/bohemian-rhapsody-guitar-pro-228902
# error with https://tabs.ultimate-guitar.com/tab/luke-bryan/play-it-again-chords-1413721
# 1930 done
# error with https://tabs.ultimate-guitar.com/tab/joji/sanctuary-chords-2732754
# error with https://tabs.ultimate-guitar.com/tab/peterpan/semua-tentang-kita-tabs-149105
# error with https://tabs.ultimate-guitar.com/tab/candlebox/far-behind-tabs-16189
# error with https://tabs.ultimate-guitar.com/tab/elevation-worship/here-as-in-heaven-chords-1781092
# error with #
# error with https://tabs.ultimate-guitar.com/tab/johnny-cash/solitary-man-chords-998141
# error with https://tabs.ultimate-guitar.com/tab/abba/gimme-gimme-gimme-chords-52946
# error with https://tabs.ultimate-guitar.com/tab/jerryc/canon-rock-chords-712976
# error with https://tabs.ultimate-guitar.com/tab/demi-lovato/wouldnt-change-a-thing-chords-970956
# error with https://tabs.ultimate-guitar.com/tab/audioslave/like-a-stone-tabs-45721
# 1940 done
# error with https://tabs.ultimate-guitar.com/tab/metallica/the-unforgiven-iii-tabs-729287
# error with https://tabs.ultimate-guitar.com/tab/jason-mraz/a-beautiful-mess-chords-665085
# error with https://tabs.ultimate-guitar.com/tab/chris-stapleton/what-are-you-listening-to-chords-1405074
# error with https://tabs.ultimate-guitar.com/tab/metallica/nothing-else-matters-guitar-pro-225443
# error with https://tabs.ultimate-guitar.com/tab/wild-cherry/play-that-funky-music-tabs-58037
# error with https://tabs.ultimate-guitar.com/tab/staind/so-far-away-chords-111051
# error with https://tabs.ultimate-guitar.com/tab/maroon-5/sunday-morning-tabs-148492
# error with https://tabs.ultimate-guitar.com/tab/misc-praise-songs/it-is-well-with-my-soul-chords-1735270
# error with https://tabs.ultimate-guitar.com/tab/joe-cocker/you-are-so-beautiful-chords-1056439
# error with https://tabs.ultimate-guitar.com/tab/the-beach-boys/wouldnt-it-be-nice-chords-16805
# 1950 done
# error with https://tabs.ultimate-guitar.com/tab/martin-garrix/in-the-name-of-love-chords-1863277
# error with https://tabs.ultimate-guitar.com/tab/efek-rumah-kaca/sebelah-mata-chords-2200663
# error with https://tabs.ultimate-guitar.com/tab/johnny-cash/hurt-chords-773909
# error with https://tabs.ultimate-guitar.com/tab/ariana-grande/into-you-chords-1842498
# error with https://tabs.ultimate-guitar.com/tab/michael-jackson/ill-be-there-chords-71844
# error with https://tabs.ultimate-guitar.com/tab/david-bowie/ashes-to-ashes-chords-981508
# error with https://tabs.ultimate-guitar.com/tab/green-day/boulevard-of-broken-dreams-chords-1007014
# error with https://tabs.ultimate-guitar.com/tab/luke-combs/she-got-the-best-of-me-chords-1727300
# error with https://tabs.ultimate-guitar.com/tab/sum-41/so-long-goodbye-chords-524040
# error with https://tabs.ultimate-guitar.com/tab/knaan/wavin-flag-chords-798536
# 1960 done
# error with https://tabs.ultimate-guitar.com/tab/the-killers/mr-brightside-tabs-202652
# error with https://tabs.ultimate-guitar.com/tab/blur/coffee-and-tv-chords-17738
# error with https://tabs.ultimate-guitar.com/tab/neil-young/the-needle-and-the-damage-done-chords-1053971
# No chords
# No chords
# No contributorshttps://tabs.ultimate-guitar.com/tab/rage-against-the-machine/rage-against-the-machine-tabs-51169
# 1970 done
# No chords
# No chords
# 1980 done
# No chords
# No chords
# No chords
# No chords
# 1990 done
# No chords
# 2000 done

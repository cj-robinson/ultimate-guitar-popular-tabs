# %% [markdown]
# # Ultimate Guitar Scrape - 1
# ## Scraping all time tabs
# *Initial scrape of top 5,000 tabs and links based on views on ultimate-guitar.com*
#
# ----
#
# **Final Project for Data & Databases**
#
# **C.J. Robinson**
#
# **Fall 2024**

# %% [markdown]
# -----
# ### Scrape main page

# %%
import re
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# Page relies heavily on JS fter loading

# %% [markdown]
# ### Shifting to Playwright

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()
await page.goto("https://www.ultimate-guitar.com/explore?order=hitstotal_desc")
# Out:
# <Response url='https://www.ultimate-guitar.com/explore?order=hitstotal_desc' request=<Request url='https://www.ultimate-guitar.com/explore?order=hitstotal_desc' method='GET'>>

# %%
html = await page.content()
soup_doc = BeautifulSoup(html, "html.parser")

# %%
table = soup_doc.find_all('article')[1]

# %%
all_songs = []

rank_counter = 1
for row in table.find_all("div", class_ = "LQUZJ")[1:]:
    song_dict = {}

    # there's no rank, so imputing one here
    song_dict['rank'] = rank_counter

    # based off of class names which...seem static
    song_dict['artist'] = row.find(class_ ="lIKMM lz4gy").text
    song_dict['song'] = row.find(class_ ="lIKMM g7KZB").text
    song_dict['ratings'] = row.find(class_ ="lIKMM eznJV").text
    song_dict['hits'] = row.find(class_ ="lIKMM UpKH8").text.strip()
    song_dict['type'] = row.find(class_ ="lIKMM PdXKy").text

    song_dict['song_link'] = row.find("a", class_ = "aPPf7 HT3w5 lBssT")['href']
    song_dict['artist_link'] = row.find("a", class_ = "aPPf7 jtEAE lBssT")['href']

    #stars are a bit interesting
    # take all full stars
    star_count = len(row.find_all("span", class_ = "kd3Q7 DSnE7")) * 1.0
    # add half stars
    star_count += len(row.find_all("span", class_ = "kd3Q7 RCXwf DSnE7")) * .5
    # we wont care about empty stars - assign star
    song_dict['star_count'] = star_count
    
    #up the counter
    rank_counter += 1

    all_songs.append(song_dict)

# %%
print(all_songs)
# Out:
# [{'rank': 1, 'artist': 'Ed Sheeran', 'song': 'Perfect', 'ratings': '48,237', 'hits': '41,204,641', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/ed-sheeran/perfect-chords-1956589', 'artist_link': 'https://www.ultimate-guitar.com/artist/ed_sheeran_30232', 'star_count': 5.0}, {'rank': 2, 'artist': 'Jeff Buckley', 'song': 'Hallelujah (ver\xa02)', 'ratings': '54,482', 'hits': '39,806,615', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/jeff-buckley/hallelujah-chords-198052', 'artist_link': 'https://www.ultimate-guitar.com/artist/jeff_buckley_9898', 'star_count': 5.0}, {'rank': 3, 'artist': 'Elvis Presley', 'song': 'Cant Help Falling In Love', 'ratings': '32,809', 'hits': '33,889,387', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/elvis-presley/cant-help-falling-in-love-chords-1086983', 'artist_link': 'https://www.ultimate-guitar.com/artist/elvis_presley_11125', 'star_count': 5.0}, {'rank': 4, 'artist': 'Passenger', 'song': 'Let Her Go', 'ratings': '24,248', 'hits': '31,904,487', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1137467', 'artist_link': 'https://www.ultimate-guitar.com/artist/passenger_21762', 'star_count': 5.0}, {'rank': 5, 'artist': 'John Legend', 'song': 'All Of Me', 'ratings': '26,699', 'hits': '29,790,419', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1248578', 'artist_link': 'https://www.ultimate-guitar.com/artist/john_legend_11714', 'star_count': 5.0}, {'rank': 6, 'artist': 'Jason Mraz', 'song': 'Im Yours (ver\xa011)', 'ratings': '16,069', 'hits': '24,611,812', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/jason-mraz/im-yours-chords-373896', 'artist_link': 'https://www.ultimate-guitar.com/artist/jason_mraz_10984', 'star_count': 5.0}, {'rank': 7, 'artist': 'Led Zeppelin', 'song': 'Stairway To Heaven', 'ratings': '14,093', 'hits': '24,568,410', 'type': 'tab', 'song_link': 'https://tabs.ultimate-guitar.com/tab/led-zeppelin/stairway-to-heaven-tabs-9488', 'artist_link': 'https://www.ultimate-guitar.com/artist/led_zeppelin_1036', 'star_count': 5.0}, {'rank': 8, 'artist': 'Radiohead', 'song': 'Creep', 'ratings': '32,992', 'hits': '22,828,385', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/radiohead/creep-chords-4169', 'artist_link': 'https://www.ultimate-guitar.com/artist/radiohead_578', 'star_count': 5.0}, {'rank': 9, 'artist': 'Ed Sheeran', 'song': 'Thinking Out Loud', 'ratings': '17,356', 'hits': '22,366,606', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/ed-sheeran/thinking-out-loud-chords-1486860', 'artist_link': 'https://www.ultimate-guitar.com/artist/ed_sheeran_30232', 'star_count': 5.0}, {'rank': 10, 'artist': 'Vance Joy', 'song': 'Riptide (ver\xa02)', 'ratings': '28,313', 'hits': '21,109,813', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/vance-joy/riptide-chords-1237247', 'artist_link': 'https://www.ultimate-guitar.com/artist/vance_joy_37940', 'star_count': 5.0}, {'rank': 11, 'artist': 'Bruno Mars', 'song': 'When I Was Your Man', 'ratings': '23,375', 'hits': '19,885,383', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/bruno-mars/when-i-was-your-man-chords-1198871', 'artist_link': 'https://www.ultimate-guitar.com/artist/bruno_mars_28280', 'star_count': 5.0}, {'rank': 12, 'artist': 'Ed Sheeran', 'song': 'Photograph', 'ratings': '19,797', 'hits': '19,427,819', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/ed-sheeran/photograph-chords-1493446', 'artist_link': 'https://www.ultimate-guitar.com/artist/ed_sheeran_30232', 'star_count': 5.0}, {'rank': 13, 'artist': 'Oasis', 'song': 'Dont Look Back In Anger', 'ratings': '21,520', 'hits': '18,503,106', 'type': 'chords', 'song_link': 'https://tabs.ultimate-guitar.com/tab/oasis/dont-look-back-in-anger-chords-6097', 'artist_link': 'https://www.ultimate-guitar.com/artist/ ...

# %%
pd.json_normalize(all_songs)
# Out:
#     rank                                     artist  \
# 0      1                                 Ed Sheeran
# 1      2                               Jeff Buckley
# 2      3                              Elvis Presley
# 3      4                                  Passenger
# 4      5                                John Legend
# 5      6                                 Jason Mraz
# 6      7                               Led Zeppelin
# 7      8                                  Radiohead
# 8      9                                 Ed Sheeran
# 9     10                                  Vance Joy
# 10    11                                 Bruno Mars
# 11    12                                 Ed Sheeran
# 12    13                                      Oasis
# 13    14                              Justin Bieber
# 14    15                                 Pink Floyd
# 15    16                                  Metallica
# 16    17                              Goo Goo Dolls
# 17    18                            Plain White T's
# 18    19                                     Eagles
# 19    20                                   Coldplay
# 20    21                                      Adele
# 21    22                               Taylor Swift
# 22    23                                   Coldplay
# 23    24                                      Oasis
# 24    25                                      Oasis
# 25    26                                     Eagles
# 26    27                                   Paramore
# 27    28                                 Ed Sheeran
# 28    29                                The Animals
# 29    30                                      Train
# 30    31                            Plain White T's
# 31    32                                The Beatles
# 32    33  Misc Soundtrack/Lady Gaga, Bradley Cooper
# 33    34                                John Denver
# 34    35                                      Oasis
# 35    36                                  Green Day
# 36    37                                    Extreme
# 37    38                                   Coldplay
# 38    39                                   Kodaline
# 39    40                                John Lennon
# 40    41                                      Adele
# 41    42                                Johnny Cash
# 42    43                                The Beatles
# 43    44                              Guns N' Roses
# 44    45                            Imagine Dragons
# 45    46                            The Cranberries
# 46    47               Creedence Clearwater Revival
# 47    48                              Lewis Capaldi
# 48    49                                The Beatles
# 49    50                              Frank Sinatra
#
#                                   song ratings        hits    type  \
# 0                              Perfect  48,237  41,204,641  chords
# 1                   Hallelujah (ver 2)  54,482  39,806,615  chords
# 2            Cant Help Falling In Love  32,809  33,889,387  chords
# 3                           Let Her Go  24,248  31,904,487  chords
# 4                            All Of Me  26,699  29,790,419  chords
# 5                    Im Yours (ver 11)  16,069  24,611,812  chords
# 6                   Stairway To Heaven  14,093  24,568,410     tab
# 7                                Creep  32,992  22,828,385  chords
# 8                    Thinking Out Loud  17,356  22,366,606  chords
# 9                      Riptide (ver 2)  28,313  21,109,813  chords
# 10                 When I Was Your Man  23,375  19,885,383  chords
# 11                          Photograph  19,797  19,427,819  chords
# 12             Dont Look Back In Anger  21,520  18,503,106  chords
# 13                       Love Yourself  15,168  18,173,424  chords
# 14                  Wish You Were Here  24,999  18,163,676  chords
# 15                Nothing Else Matters   4,832  18,080,223     tab
# 16                        Iris (ver 4)   9,404  17,073,727  chords
# 17                            Airplane     746  16,906,534     tab
# 18                    Hotel California  32,916  16,593,747  chords
# 19               The Scientist (ver 4)  12,953  16,408,355  chords
# 20            Someone Like You (ver 2)   4,210  16,214,512  chords
# 21                          Love Story  11,796  14,917,838  chords
# 22                        Viva La Vida  18,604  14,687,168  chords
# 23                  Wonderwall (ver 3)  11,675  14,503,026  chords
# 24                  Wonderwall (ver 2)   9,245  14,151,409  chords
# 25            Hotel California (ver 2)   2,748  13,492,733     tab
# 26                  The Only Exception  10,663  13,459,721  chords
# 27                  I See Fire (ver 3)  12,520  13,309,117  chords
# 28             House Of The Rising Sun  16,305  13,196,043  chords
# 29             Hey Soul Sister (ver 2)   9,881  13,095,563  chords
# 30           Hey There Delilah (ver 2)  12,427  12,625,412  chords
# 31                           Let It Be  12,242  12,601,443  chords
# 32    A Star Is Born - Shallow (ver 2)  19,349  12,424,092  chords
# 33  Take Me Home Country Roads (ver 5)  18,117  12,364,546  chords
# 34                          Wonderwall   2,259  12,272,812  chords
# 35  Boulevard Of Broken Dreams (ver 3)  12,390  12,187,604  chords
# 36                     More Than Words   7,635  11,965,760  chords
# 37                      Yellow (ver 2)  20,731  11,950,173  chords
# 38                          All I Want  12,320  11,933,742  chords
# 39                             Imagine  13,856  11,808,416  chords
# 40                    Someone Like You  15,900  11,588,587  chords
# 41                                Hurt  19,446  11,548,456  chords
# 42                           Yesterday  10,941  11,262,352  chords
# 43          Sweet Child O Mine (ver 2)   3,179  11,244,250     tab
# 44                         Radioactive  20,698  11,167,838  chords
# 45                              Zombie  16,745  10,857,192  chords
# 46         Have You Ever Seen The Rain  22,744  10,833,515  chords
# 47                   Someone You Loved  23,030  10,810,854  chords
# 48                            Hey Jude   4,597  10,783,435  chords
# 49          Fly Me To The Moon (ver 2)  14,022  10,757,403  chords
#
#                                             song_link  \
# 0   https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 1   https://tabs.ultimate-guitar.com/tab/jeff-buck...
# 2   https://tabs.ultimate-guitar.com/tab/elvis-pre...
# 3   https://tabs.ultimate-guitar.com/tab/passenger...
# 4   https://tabs.ultimate-guitar.com/tab/john-lege...
# 5   https://tabs.ultimate-guitar.com/tab/jason-mra...
# 6   https://tabs.ultimate-guitar.com/tab/led-zeppe...
# 7   https://tabs.ultimate-guitar.com/tab/radiohead...
# 8   https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 9   https://tabs.ultimate-guitar.com/tab/vance-joy...
# 10  https://tabs.ultimate-guitar.com/tab/bruno-mar...
# 11  https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 12  https://tabs.ultimate-guitar.com/tab/oasis/don...
# 13  https://tabs.ultimate-guitar.com/tab/justin-bi...
# 14  https://tabs.ultimate-guitar.com/tab/pink-floy...
# 15  https://tabs.ultimate-guitar.com/tab/metallica...
# 16  https://tabs.ultimate-guitar.com/tab/goo-goo-d...
# 17  https://tabs.ultimate-guitar.com/tab/plain-whi...
# 18  https://tabs.ultimate-guitar.com/tab/eagles/ho...
# 19  https://tabs.ultimate-guitar.com/tab/coldplay/...
# 20  https://tabs.ultimate-guitar.com/tab/adele/som...
# 21  https://tabs.ultimate-guitar.com/tab/taylor-sw...
# 22  https://tabs.ultimate-guitar.com/tab/coldplay/...
# 23  https://tabs.ultimate-guitar.com/tab/oasis/won...
# 24  https://tabs.ultimate-guitar.com/tab/oasis/won...
# 25  https://tabs.ultimate-guitar.com/tab/eagles/ho...
# 26  https://tabs.ultimate-guitar.com/tab/paramore/...
# 27  https://tabs.ultimate-guitar.com/tab/ed-sheera...
# 28  https://tabs.ultimate-guitar.com/tab/the-anima...
# 29  https://tabs.ultimate-guitar.com/tab/train/hey...
# 30  https://tabs.ultimate-guitar.com/tab/plain-whi...
# 31  https://tabs.ultimate-guitar.com/tab/the-beatl...
# 32  https://tabs.ultimate-guitar.com/tab/misc-soun...
# 33  https://tabs.ultimate-guitar.com/tab/john-denv...
# 34  https://tabs.ultimate-guitar.com/tab/oasis/won...
# 35  https://tabs.ultimate-guitar.com/tab/green-day...
# 36  https://tabs.ultimate-guitar.com/tab/extreme/m...
# 37  https://tabs.ultimate-guitar.com/tab/coldplay/...
# 38  https://tabs.ultimate-guitar.com/tab/kodaline/...
# 39  https://tabs.ultimate-guitar.com/tab/john-lenn...
# 40  https://tabs.ultimate-guitar.com/tab/adele/som...
# 41  https://tabs.ultimate-guitar.com/tab/johnny-ca...
# 42  https://tabs.ultimate-guitar.com/tab/the-beatl...
# 43  https://tabs.ultimate-guitar.com/tab/guns-n-ro...
# 44  https://tabs.ultimate-guitar.com/tab/imagine-d...
# 45  https://tabs.ultimate-guitar.com/tab/the-cranb...
# 46  https://tabs.ultimate-guitar.com/tab/creedence...
# 47  https://tabs.ultimate-guitar.com/tab/lewis-cap...
# 48  https://tabs.ultimate-guitar.com/tab/the-beatl...
# 49  https://tabs.ultimate-guitar.com/tab/frank-sin...
#
#                                           artist_link  star_count
# 0   https://www.ultimate-guitar.com/artist/ed_shee...         5.0
# 1   https://www.ultimate-guitar.com/artist/jeff_bu...         5.0
# 2   https://www.ultimate-guitar.com/artist/elvis_p...         5.0
# 3   https://www.ultimate-guitar.com/artist/passeng...         5.0
# 4   https://www.ultimate-guitar.com/artist/john_le...         5.0
# 5   https://www.ultimate-guitar.com/artist/jason_m...         5.0
# 6   https://www.ultimate-guitar.com/artist/led_zep...         5.0
# 7   https://www.ultimate-guitar.com/artist/radiohe...         5.0
# 8   https://www.ultimate-guitar.com/artist/ed_shee...         5.0
# 9   https://www.ultimate-guitar.com/artist/vance_j...         5.0
# 10  https://www.ultimate-guitar.com/artist/bruno_m...         5.0
# 11  https://www.ultimate-guitar.com/artist/ed_shee...         5.0
# 12   https://www.ultimate-guitar.com/artist/oasis_734         5.0
# 13  https://www.ultimate-guitar.com/artist/justin_...         5.0
# 14  https://www.ultimate-guitar.com/artist/pink_fl...         5.0
# 15  https://www.ultimate-guitar.com/artist/metalli...         4.5
# 16  https://www.ultimate-guitar.com/artist/goo_goo...         5.0
# 17  https://www.ultimate-guitar.com/artist/plain_w...         4.5
# 18  https://www.ultimate-guitar.com/artist/eagles_...         5.0
# 19  https://www.ultimate-guitar.com/artist/coldpla...         5.0
# 20  https://www.ultimate-guitar.com/artist/adele_2...         5.0
# 21  https://www.ultimate-guitar.com/artist/taylor_...         5.0
# 22  https://www.ultimate-guitar.com/artist/coldpla...         5.0
# 23   https://www.ultimate-guitar.com/artist/oasis_734         5.0
# 24   https://www.ultimate-guitar.com/artist/oasis_734         5.0
# 25  https://www.ultimate-guitar.com/artist/eagles_...         4.5
# 26  https://www.ultimate-guitar.com/artist/paramor...         5.0
# 27  https://www.ultimate-guitar.com/artist/ed_shee...         5.0
# 28  https://www.ultimate-guitar.com/artist/the_ani...         5.0
# 29   https://www.ultimate-guitar.com/artist/train_250         5.0
# 30  https://www.ultimate-guitar.com/artist/plain_w...         5.0
# 31  https://www.ultimate-guitar.com/artist/the_bea...         5.0
# 32  https://www.ultimate-guitar.com/artist/misc_so...         5.0
# 33  https://www.ultimate-guitar.com/artist/john_de...         5.0
# 34   https://www.ultimate-guitar.com/artist/oasis_734         4.5
# 35  https://www.ultimate-guitar.com/artist/green_d...         5.0
# 36  https://www.ultimate-guitar.com/artist/extreme...         5.0
# 37  https://www.ultimate-guitar.com/artist/coldpla...         5.0
# 38  https://www.ultimate-guitar.com/artist/kodalin...         5.0
# 39  https://www.ultimate-guitar.com/artist/john_le...         5.0
# 40  https://www.ultimate-guitar.com/artist/adele_2...         5.0
# 41  https://www.ultimate-guitar.com/artist/johnny_...         5.0
# 42  https://www.ultimate-guitar.com/artist/the_bea...         5.0
# 43  https://www.ultimate-guitar.com/artist/guns_n_...         4.5
# 44  https://www.ultimate-guitar.com/artist/imagine...         5.0
# 45  https://www.ultimate-guitar.com/artist/the_cra...         5.0
# 46  https://www.ultimate-guitar.com/artist/creeden...         5.0
# 47  https://www.ultimate-guitar.com/artist/lewis_c...         5.0
# 48  https://www.ultimate-guitar.com/artist/the_bea...         5.0
# 49  https://www.ultimate-guitar.com/artist/frank_s...         5.0

# %% [markdown]
# ### Loop through all the pages!

# %%
# start up the page!
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

# %%
all_songs = []
rank_counter = 1

for page_num in range(1,101):
    url = f"https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page={str(page_num)}"
    print(url)
    await page.goto(url)
    await page.get_by_text("Artist", exact=True).wait_for()
    html = await page.content()
    soup_doc = BeautifulSoup(html, "html.parser")
    table = soup_doc.find_all('article')[1]
    
    for row in table.find_all("div", class_ = "LQUZJ")[1:]:
        song_dict = {}

        # there's no rank, so imputing one here
        song_dict['rank'] = rank_counter
    
        # based off of class names which...seem static
        try:
            #get just raw artist text (feat, &, commas)
            artist_list = []
            song_dict['artist'] = row.find(class_ ="lIKMM lz4gy").text

            # get each individual artist in a list...just in case!
            for artist in row.find_all('a', class_ ="aPPf7 jtEAE lBssT"):
                artist_list.append(artist.text)
            
            song_dict['artist_list'] = artist_list
        except:
            print(f"No artist for {rank_counter} rank")
            
        try:    
            song_dict['song'] = row.find(class_ ="lIKMM g7KZB").text
        except:
            print(f"No song for {rank_counter} rank")

        try:
            song_dict['ratings'] = row.find(class_ ="lIKMM eznJV").text
        except:
            print(f"No ratings for {rank_counter} rank")
            
        try:   
            song_dict['hits'] = row.find(class_ ="lIKMM UpKH8").text.strip()
        except:
            print(f"No hits for {rank_counter} rank")
            
        try:    
            song_dict['type'] = row.find(class_ ="lIKMM PdXKy").text
        except:
            print(f"No type for {rank_counter} rank")
    
        song_dict['song_link'] = row.find("a", class_ = "aPPf7 HT3w5 lBssT")['href']
        song_dict['artist_link'] = row.find("a", class_ = "aPPf7 jtEAE lBssT")['href']
    
        #stars are a bit interesting
        # take all full stars
        star_count = len(row.find_all("span", class_ = "kd3Q7 DSnE7")) * 1.0
        # add half stars
        star_count += len(row.find_all("span", class_ = "kd3Q7 RCXwf DSnE7")) * .5
        # we wont care about empty stars - assign star
        try:
            song_dict['star_count'] = star_count
        except:
            print(f"No stars for {rank_counter} rank")
        
        #up the counter
        rank_counter += 1
    
        all_songs.append(song_dict)

    # wait a couple seconds
    time.sleep(5)

df = pd.json_normalize(all_songs)
df.to_csv("top_songs.csv")
# Out:
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=1
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=2
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=3
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=4
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=5
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=6
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=7
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=8
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=9
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=10
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=11
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=12
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=13
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=14
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=15
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=16
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=17
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=18
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=19
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=20
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=21
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=22
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=23
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=24
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=25
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=26
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=27
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=28
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=29
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=30
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=31
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=32
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=33
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=34
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=35
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=36
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=37
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=38
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=39
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=40
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=41
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=42
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=43
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=44
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=45
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=46
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=47
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=48
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=49
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=50
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=51
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=52
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=53
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=54
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=55
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=56
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=57
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=58
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=59
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=60
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=61
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=62
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=63
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=64
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=65
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=66
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=67
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=68
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=69
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=70
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=71
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=72
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=73
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=74
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=75
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=76
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=77
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=78
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=79
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=80
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=81
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=82
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=83
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=84
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=85
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=86
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=87
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=88
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=89
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=90
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=91
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=92
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=93
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=94
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=95
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=96
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=97
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=98
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=99
# https://www.ultimate-guitar.com/explore?order=hitstotal_desc&page=100
